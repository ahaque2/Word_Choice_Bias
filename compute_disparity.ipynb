# %%
#Compute disparity between word-pairs identified for each entity reference

from nltk.corpus import wordnet as wn
import spacy
import sys
import math

sys.stdout.write('Loading SpaCy model...\n')
lg = spacy.load('en_core_web_lg')
sys.stdout.write('Loaded.\n')
# Out:
# Loading SpaCy model...
# Loaded.

# %%
def get_pickle_data(filepath):
    
    import pickle
    ent_clusters = None
    with open(filepath, 'rb') as f:
        ent_clusters = pickle.load(f)
    return ent_clusters

def save_pickle_data(filepath, data):
    
    with open(filepath, 'wb') as f:
        pickle.dump(data, f)

def merge_case_sensitive_keys(d):
    
    d2 = dict()
    for key in d:
        key_low = key.lower()
        if(key_low in d2):
            d2[key_low] += d[key]        
        else:
            d2[key_low] = d[key]
            
    return d2

def process_dict(d):

    d2 = dict()
    for key in d:
        d[key]['adjectives'] = merge_case_sensitive_keys(d[key]['adjectives'])
        
    return d

def get_candidate_adj_counts(ent_adj_media_1, ent_adj_media_2, entity, MAX_FREQUENCY, MIN_FREQUENCY):
    
    media_1_adj_freq = ent_adj_media_1[entity]['adjectives']
    media_2_adj_freq = ent_adj_media_2[entity]['adjectives']
    
    combined_adj_freq = media_1_adj_freq.copy()
    for word in media_2_adj_freq:
        if word in combined_adj_freq:
            combined_adj_freq[word] += media_2_adj_freq[word]
        else:
            combined_adj_freq[word] = media_2_adj_freq[word]

    # keep words based on frequency
    candidate_adj_freq_dict = {}
    for word in combined_adj_freq:
        if combined_adj_freq[word] >= MIN_FREQUENCY and combined_adj_freq[word] <= MAX_FREQUENCY:
            candidate_adj_freq_dict[word] = combined_adj_freq[word]
    
    return candidate_adj_freq_dict, media_1_adj_freq, media_2_adj_freq

def get_word_synonym_pairs(word_list):
    word_pairs = []
    for word in word_list:
        for syn in wn.synsets(word):
            for l in syn.lemmas():
                if l.name() == word:
                    continue
                if l.name() in word_list:
                    word_pairs.append(sorted([word, l.name()]))

    word_pairs = [t for t in (set(tuple(wp) for wp in word_pairs))] 

    return word_pairs

def get_disparity(word_pairs, positive_counts, negative_counts, disparity_threshold):
    
    tool = []
    for word1, word2 in word_pairs:
        f_pos_1 = float(positive_counts[word1]) if word1 in positive_counts else 0.1
        f_pos_2 = float(positive_counts[word2]) if word2 in positive_counts else 0.1
        f_neg_1 = float(negative_counts[word1]) if word1 in negative_counts else 0.1
        f_neg_2 = float(negative_counts[word2]) if word2 in negative_counts else 0.1

        disparity1 = f_pos_1 / f_neg_1
        disparity2 = f_neg_2 / f_pos_2
        disparity = f_pos_1 * f_neg_2 / f_neg_1 / f_pos_2

        if disparity < 1.0:
            # word 1 is negative
            tool.append((word2, 1.0/disparity2, word1, 1.0/disparity1))
        else:
            tool.append((word1, disparity1, word2, disparity2))

    tool.sort(key=lambda x: x[1]*x[3], reverse=True)

    final_pairs = []
    for tp in tool:
        if tp[1]>=disparity_threshold and tp[3]>=disparity_threshold:
            final_pairs.append(tp)
            
    return final_pairs
    
def get_result_pairs(media_1_file, media_2_file, max_freq, min_freq, disparity_threshold):

    entity_adj_pairs_media_1 = get_pickle_data(media_1_file)
    entity_adj_pairs_media_2 = get_pickle_data(media_2_file)
    
    entity_adj_pairs_media_1 = process_dict(entity_adj_pairs_media_1)
    entity_adj_pairs_media_2 = process_dict(entity_adj_pairs_media_2)
    
    entities1 = list(entity_adj_pairs_media_1.keys())
    entities2 = list(entity_adj_pairs_media_2.keys())
    combined_entities = list(set(entities1) & set(entities2)) 

    print("Number of entities in Media 1 ", len(entities1))
    print("Number of entities in Media 2 ", len(entities2))
    print("Number of entities common in both ", len(combined_entities))

    ent_word_pairs = dict()
    for entity in combined_entities:
        cluster_ent = entity_adj_pairs_media_1[entity]['person_entities']
        candidate_adj_freq_dict, media_1_adj_freq, media_2_adj_freq = get_candidate_adj_counts(entity_adj_pairs_media_1, entity_adj_pairs_media_2, entity, MAX_FREQUENCY, MIN_FREQUENCY)
        if(len(candidate_adj_freq_dict) > 25):
            word_list = list(candidate_adj_freq_dict.keys())
            word_pairs = get_word_synonym_pairs(word_list)
            final_pairs = get_disparity(word_pairs, media_1_adj_freq, media_2_adj_freq, disparity_threshold)
            ent_word_pairs[entity] = {'adj_pairs':final_pairs, 'entity_cluster':cluster_ent}
            
    return ent_word_pairs

def get_entity_results(word_pair_dict, entity):
    
    ent_adj_pair = dict()    
    for key in word_pair_dict:
        entity_cls = word_pair_dict[key]['entity_cluster']
        if(any(True for ent in entity_cls if entity in ent)):
            ent_adj_pair[key] = word_pair_dict[key]
        
    return ent_adj_pair

# l = {2:{'per':"amanul", 'adjectives': {"A":1, "a":3, "Ca": 3, "ca":1}}, 3:{'per':"aamanul", 'adjectives': {"A":4, "a":3, "Ca": 9, "ca":1}}}
# print(process_dict(l))

# %%
max_freq = 500 # out of 10000
min_freq = 2 # out of 10000
disparity_threshold = 1.0

media_1_file = "Nammed_entities/ent_adj_pairs_Breitbart.pickle"
media_2_file = "Nammed_entities/ent_adj_pairs_NYT.pickle"
media_3_file = "Nammed_entities/ent_adj_pairs_BI.pickle"
media_4_file = "Nammed_entities/ent_adj_pairs_CNN.pickle"

ent_word_pairs = get_result_pairs(media_1_file, media_2_file, max_freq, min_freq, disparity_threshold)

ent_adj_p = get_entity_results(ent_word_pairs, "Trump")
print(len(ent_adj_p[1045]['adj_pairs']))
ent_adj_p
# Out:
# Number of entities in Media 1  1015
# Number of entities in Media 2  1393
# Number of entities common in both  693
# 546
# {146: {'adj_pairs': [], 'entity_cluster': ['Eric Trump']},
#  519: {'adj_pairs': [('young', 2.0, 'new', 1.0)],
#   'entity_cluster': ['Melania Trump']},
#  1045: {'adj_pairs': [('upcoming', 340.0, 'coming', 30.0),
#    ('deplorable', 110.0, 'reprehensible', 40.0),
#    ('alien', 110.0, 'alienated', 40.0),
#    ('alien', 110.0, 'exotic', 20.0),
#    ('exact', 109.99999999999999, 'accurate', 20.0),
#    ('cowardly', 40.0, 'fearful', 50.0),
#    ('despicable', 90.0, 'worthless', 20.0),
#    ('greedy', 30.0, 'avid', 40.0),
#    ('wild', 2.0, 'risky', 589.9999999999999),
#    ('speculative', 2.0, 'risky', 589.9999999999999),
#    ('southeast', 20.0, 'southeastern', 50.0),
#    ('sublime', 20.0, 'lofty', 40.0),
#    ('sorry', 40.0, 'regretful', 20.0),
#    ('tantamount', 20.0, 'equivalent', 40.0),
#    ('eminent', 20.0, 'lofty', 40.0),
#    ('bad', 1.024390243902439, 'risky', 590.0),
#    ('working', 30.0, 'functional', 20.0),
#    ('fictional', 30.0, 'fabricated', 20.0),
#    ('slippery', 20.0, 'tricky', 30.0),
#    ('transnational', 30.0, 'multinational', 20.0),
#    ('outstanding', 6.0, 'striking', 80.0),
#    ('awful', 9.0, 'fearful', 50.0),
#    ('exact', 110.0, 'precise', 4.0),
#    ('sour', 20.0, 'sullen', 20.0),
#    ('measly', 20.0, 'paltry', 20.0),
#    ('solemn', 20.0, 'grave', 20.0),
#    ('upcoming', 340.0, 'forthcoming', 1.0),
#    ('homosexual', 60.0, 'gay', 5.538461538461538),
#    ('salient', 4.0, 'striking', 80.0),
#    ('whole', 1.4583333333333333, 'unanimous', 200.0),
#    ('detrimental', 40.0, 'damaging', 6.5),
#    ('hefty', 30.0, 'sizable', 8.0),
#    ('vicious', 6.0, 'reprehensible', 40.0),
#    ('outdoor', 2.0, 'outside', 110.0),
#    ('intimate', 2.0, 'informal', 100.0),
#    ('alien', 110.0, 'disaffected', 1.8),
#    ('sorry', 40.0, 'dark', 4.875),
#    ('despicable', 90.0, 'vile', 2.0),
#    ('alien', 110.0, 'foreign', 1.4757281553398058),
#    ('articulate', 8.0, 'pronounced', 20.0),
#    ('disruptive', 3.0, 'turbulent', 50.0),
#    ('confused', 3.0, 'obscure', 50.0),
#    ('isolated', 3.0, 'obscure', 50.0),
#    ('impulsive', 7.0, 'hotheaded', 20.0),
#    ('loose', 1.3333333333333333, 'informal', 100.0),
#    ('terrible', 2.625, 'fearful', 50.0),
#    ('following', 100.0, 'next', 1.31),
#    ('absolute', 18.0, 'sheer', 7.0),
#    ('soft', 2.5, 'delicate', 50.0),
#    ('mean', 60.0, 'tight', 2.0),
#    ('vitriolic', 2.0, 'caustic', 60.0),
#    ('okay', 60.0, 'fine', 2.0),
#    ('unique', 3.0, 'singular', 40.0),
#    ('partial', 6.0, 'fond', 20.0),
#    ('sorry', 40.0, 'grim', 3.0),
#    ('respective', 60.0, 'several', 1.9537037037037037),
#    ('alien', 110.0, 'unknown', 1.0),
#    ('documentary', 110.0, 'objective', 1.0),
#    ('hopeful', 2.6363636363636367, 'bright', 40.0),
#    ('working', 30.0, 'running', 3.5),
#    ('live', 1.5, 'lasting', 70.0),
#    ('smart', 2.5999999999999996, 'bright', 40.0),
#    ('veiled', 2.0, 'obscure', 50.0),
#    ('sorry', 40.0, 'dismal', 2.5),
#    ('brave', 2.5, 'enduring', 40.0),
#    ('heroic', 2.0, 'expansive', 50.0),
#    ('vitriolic', 2.0, 'acrid', 50.0),
#    ('sour', 20.0, 'dark', 4.875),
#    ('wise', 40.0, 'fresh', 2.4),
#    ('funny', 2.3333333333333335, 'singular', 40.0),
#    ('nude', 30.0, 'bare', 3.0),
#    ('plush', 1.0, 'lavish', 90.0),
#    ('isolated', 3.0, 'stray', 30.0),
#    ('despicable', 90.0, 'unworthy', 1.0),
#    ('mean', 60.0, 'average', 1.4),
#    ('perfect', 2.0, 'gross', 40.0),
#    ('crude', 2.0, 'gross', 40.0),
#    ('touching', 20.0, 'equal', 4.0),
#    ('peculiar', 2.0, 'singular', 40.0),
#    ('wild', 2.0, 'baseless', 40.0),
#    ('unwarranted', 2.0, 'baseless', 40.0),
#    ('odd', 2.0, 'singular', 40.0),
#    ('prejudiced', 4.0, 'discriminatory', 20.0),
#    ('old', 1.28, 'onetime', 60.0),
#    ('permanent', 1.0, 'lasting', 70.0),
#    ('unnamed', 70.0, 'unknown', 1.0),
#    ('loaded', 1.0, 'affluent', 70.0),
#    ('disorderly', 20.0, 'chaotic', 3.3333333333333335),
#    ('incredible', 3.3333333333333335, 'unbelievable', 20.0),
#    ('correct', 1.6, 'disciplined', 40.0),
#    ('hefty', 30.0, 'powerful', 2.1176470588235294),
#    ('awful', 9.0, 'painful', 7.0),
#    ('big', 1.045045045045045, 'boastful', 60.0),
#    ('easy', 3.090909090909091, 'light', 20.0),
#    ('superb', 20.0, 'brilliant', 3.0),
#    ('ominous', 3.0, 'sinister', 20.0),
#    ('adult', 1.5, 'grown', 40.0),
#    ('live', 1.5, 'enduring', 40.0),
#    ('ominous', 3.0, 'threatening', 20.0),
#    ('preeminent', 40.0, 'leading', 1.5),
#    ('glorious', 20.0, 'brilliant', 3.0),
#    ('solemn', 20.0, 'sober', 3.0),
#    ('gruesome', 20.0, 'grim', 3.0),
#    ('blatant', 30.0, 'vociferous', 2.0),
#    ('sublime', 20.0, 'grand', 3.0),
#    ('ominous', 3.0, 'menacing', 20.0),
#    ('unique', 3.0, 'unparalleled', 20.0),
#    ('criminal', 1.4285714285714286, 'reprehensible', 40.0),
#    ('ferocious', 4.0, 'fierce', 14.0),
#    ('stark', 1.3333333333333333, 'gross', 40.0),
#    ('utter', 1.3333333333333333, 'gross', 40.0),
#    ('hopeful', 2.6363636363636362, 'promising', 20.0),
#    ('specialized', 20.0, 'narrow', 2.5999999999999996),
#    ('veteran', 1.7, 'seasoned', 30.0),
#    ('proud', 1.2727272727272727, 'lofty', 40.0),
#    ('constitutional', 2.5, 'inherent', 20.0),
#    ('incompetent', 1.0, 'incapable', 50.0),
#    ('unknown', 1.0, 'obscure', 50.0),
#    ('horrifying', 50.0, 'horrible', 1.0),
#    ('total', 1.6666666666666667, 'coming', 30.0),
#    ('dreadful', 1.0, 'fearful', 50.0),
#    ('good', 1.5853658536585367, 'adept', 30.0),
#    ('violent', 3.3636363636363633, 'fierce', 14.0),
#    ('outstanding', 6.0, 'prominent', 7.5),
#    ('doubtful', 1.5, 'dubious', 30.0),
#    ('alternate', 1.5, 'flip', 30.0),
#    ('secret', 2.25, 'occult', 20.0),
#    ('violent', 3.3636363636363633, 'vehement', 13.0),
#    ('sure', 1.0769230769230769, 'trusted', 40.0),
#    ('sorry', 40.0, 'blue', 1.0714285714285714),
#    ('rival', 10.666666666666666, 'equal', 4.0),
#    ('big', 1.045045045045045, 'grown', 40.0),
#    ('curious', 1.0, 'singular', 40.0),
#    ('dear', 20.0, 'heartfelt', 2.0),
#    ('compulsive', 20.0, 'determined', 2.0),
#    ('countless', 2.0, 'innumerable', 20.0),
#    ('wild', 2.0, 'groundless', 20.0),
#    ('catastrophic', 2.0, 'ruinous', 20.0),
#    ('golden', 1.0, 'gilded', 40.0),
#    ('earnest', 20.0, 'sincere', 2.0),
#    ('unwarranted', 2.0, 'groundless', 20.0),
#    ('wicked', 20.0, 'distasteful', 2.0),
#    ('ok', 20.0, 'fine', 2.0),
#    ('earnest', 20.0, 'heartfelt', 2.0),
#    ('mad', 2.0, 'sore', 20.0),
#    ('unequivocal', 1.0, 'definitive', 40.0),
#    ('advanced', 1.0, 'sophisticated', 40.0),
#    ('solemn', 20.0, 'sincere', 2.0),
#    ('insurgent', 2.0, 'subversive', 20.0),
#    ('clean', 1.75, 'light', 20.0),
#    ('phony', 6.666666666666667, 'bogus', 5.0),
#    ('wicked', 20.0, 'severe', 1.6666666666666667),
#    ('naughty', 30.0, 'blue', 1.0714285714285714),
#    ('scared', 1.6, 'frightened', 20.0),
#    ('nude', 30.0, 'naked', 1.0),
#    ('busy', 1.0, 'occupied', 30.0),
#    ('advanced', 1.0, 'innovative', 30.0),
#    ('comedian', 30.0, 'comic', 1.0),
#    ('scary', 1.5, 'chilling', 20.0),
#    ('forthcoming', 1.0, 'coming', 30.0),
#    ('keen', 1.0, 'acute', 30.0),
#    ('aware', 1.0, 'mindful', 30.0),
#    ('stellar', 20.0, 'leading', 1.5),
#    ('damn', 30.0, 'bloody', 1.0),
#    ('salient', 4.0, 'prominent', 7.5),
#    ('coherent', 1.5, 'tenacious', 20.0),
#    ('firm', 1.0, 'unwavering', 30.0),
#    ('hefty', 30.0, 'healthy', 1.0),
#    ('rude', 20.0, 'raw', 1.5),
#    ('exceptional', 20.0, 'particular', 1.4),
#    ('dear', 20.0, 'near', 1.3333333333333333),
#    ('loose', 1.3333333333333333, 'light', 20.0),
#    ('ugly', 1.2857142857142858, 'worthless', 20.0),
#    ('sour', 20.0, 'false', 1.2857142857142856),
#    ('faux', 20.0, 'false', 1.2857142857142856),
#    ('quiet', 1.25, 'muted', 20.0),
#    ('quiet', 1.25, 'restrained', 20.0),
#    ('tough', 1.2121212121212122, 'problematic', 20.0),
#    ('essential', 1.2, 'indispensable', 20.0),
#    ('faux', 20.0, 'fake', 1.1951219512195121),
#    ('feasible', 1.0, 'viable', 23.0),
#    ('double', 1.1, 'dual', 20.0),
#    ('full', 1.0571428571428572, 'replete', 20.0),
#    ('bad', 1.024390243902439, 'regretful', 20.0),
#    ('crude', 2.0, 'vulgar', 10.166666666666666),
#    ('operational', 1.0, 'functional', 20.0),
#    ('rowdy', 20.0, 'raucous', 1.0),
#    ('brave', 2.5, 'audacious', 8.0),
#    ('infantile', 20.0, 'childish', 1.0),
#    ('innate', 20.0, 'natural', 1.0),
#    ('unrehearsed', 1.0, 'offhand', 20.0),
#    ('repulsive', 1.0, 'obscene', 20.0),
#    ('rude', 20.0, 'natural', 1.0),
#    ('slanted', 1.0, 'lean', 20.0),
#    ('intimate', 2.0, 'internal', 10.0),
#    ('unhinged', 20.0, 'crazy', 1.0),
#    ('connected', 1.0, 'attached', 20.0),
#    ('fallen', 1.0, 'light', 20.0),
#    ('bothersome', 20.0, 'vexing', 1.0),
#    ('wicked', 20.0, 'foul', 1.0),
#    ('unworthy', 1.0, 'worthless', 20.0),
#    ('reliable', 1.0, 'authentic', 20.0),
#    ('apt', 1.0, 'liable', 20.0),
#    ('defenseless', 20.0, 'naked', 1.0),
#    ('dissatisfied', 1.0, 'disgruntled', 20.0),
#    ('glorious', 20.0, 'magnificent', 1.0),
#    ('terrible', 2.625, 'painful', 7.0),
#    ('silly', 3.0, 'pathetic', 6.0),
#    ('mild', 3.0, 'modest', 5.5),
#    ('firm', 1.0, 'steadfast', 16.0),
#    ('staunch', 1.0, 'steadfast', 16.0),
#    ('awful', 9.0, 'dire', 1.75),
#    ('heavyweight', 5.0, 'giant', 3.0),
#    ('vicious', 6.0, 'brutal', 2.5),
#    ('violent', 3.3636363636363633, 'red', 4.4),
#    ('shocking', 7.0, 'lurid', 2.0),
#    ('ridiculous', 2.3333333333333335, 'pathetic', 6.0),
#    ('savage', 1.0, 'fierce', 14.0),
#    ('brave', 2.5, 'gay', 5.538461538461538),
#    ('occasional', 3.0, 'casual', 4.0),
#    ('fat', 9.0, 'rich', 1.3333333333333333),
#    ('everyday', 3.0, 'casual', 4.0),
#    ('awful', 9.0, 'tremendous', 1.2777777777777777),
#    ('sick', 3.75, 'grim', 3.0),
#    ('organized', 5.0, 'direct', 2.2142857142857144),
#    ('contrary', 3.5, 'opposite', 3.0),
#    ('open', 1.45, 'receptive', 7.0),
#    ('easy', 3.090909090909091, 'comfortable', 3.25),
#    ('bold', 1.4285714285714286, 'sheer', 7.0),
#    ('simple', 3.25, 'bare', 3.0),
#    ('negative', 1.4705882352941175, 'damaging', 6.5),
#    ('wide', 1.090909090909091, 'extensive', 8.75),
#    ('easy', 3.090909090909091, 'prosperous', 3.0),
#    ('fat', 9.0, 'productive', 1.0),
#    ('awful', 9.0, 'dreadful', 1.0),
#    ('awful', 9.0, 'awed', 1.0),
#    ('confused', 3.0, 'lost', 3.0),
#    ('coordinated', 3.0, 'unified', 3.0),
#    ('astounding', 3.0, 'astonishing', 3.0),
#    ('intimate', 2.0, 'sexual', 4.181818181818182),
#    ('essential', 1.2, 'crucial', 6.833333333333334),
#    ('disruptive', 3.0, 'troubled', 2.6666666666666665),
#    ('ferocious', 4.0, 'furious', 2.0),
#    ('healthy', 1.0, 'sizable', 8.0),
#    ('phony', 6.666666666666667, 'fake', 1.1951219512195121),
#    ('big', 1.045045045045045, 'prominent', 7.5),
#    ('fiscal', 1.0, 'financial', 7.458333333333333),
#    ('fellow', 2.4814814814814814, 'associate', 3.0),
#    ('lengthy', 1.0, 'extended', 7.0),
#    ('dreadful', 1.0, 'painful', 7.0),
#    ('alternate', 1.5, 'alternative', 4.5),
#    ('daily', 1.6666666666666667, 'casual', 4.0),
#    ('straight', 3.0, 'direct', 2.2142857142857144),
#    ('imperfect', 3.0, 'weak', 2.1818181818181817),
#    ('very', 2.533333333333333, 'real', 2.576642335766423),
#    ('crude', 2.0, 'rough', 3.25),
#    ('alive', 1.25, 'active', 5.0),
#    ('smart', 2.5999999999999996, 'fresh', 2.4),
#    ('outspoken', 2.2222222222222223, 'vocal', 2.75),
#    ('secret', 2.25, 'private', 2.685714285714286),
#    ('disruptive', 3.0, 'tumultuous', 2.0),
#    ('vicious', 6.0, 'savage', 1.0),
#    ('unwarranted', 2.0, 'unfounded', 3.0),
#    ('vicious', 6.0, 'poisonous', 1.0),
#    ('wild', 2.0, 'unfounded', 3.0),
#    ('heroic', 2.0, 'grand', 3.0),
#    ('outgoing', 6.0, 'forthcoming', 1.0),
#    ('amazing', 2.0, 'astonishing', 3.0),
#    ('vitriolic', 2.0, 'bitter', 3.0),
#    ('unknown', 1.0, 'strange', 6.0),
#    ('secret', 2.25, 'confidential', 2.5),
#    ('outspoken', 2.2222222222222223, 'blunt', 2.5),
#    ('stark', 1.3333333333333333, 'bleak', 4.0),
#    ('literal', 2.0, 'real', 2.576642335766423),
#    ('dynamic', 1.0, 'active', 5.0),
#    ('crude', 2.0, 'blunt', 2.5),
#    ('frank', 2.0, 'blunt', 2.5),
#    ('regular', 1.6666666666666667, 'steady', 3.0),
#    ('introductory', 2.0, 'basic', 2.5),
#    ('loaded', 1.0, 'wealthy', 4.818181818181818),
#    ('disappointed', 3.0, 'frustrated', 1.6),
#    ('actual', 1.2, 'factual', 4.0),
#    ('good', 1.5853658536585367, 'beneficial', 3.0),
#    ('shrill', 1.0, 'sharp', 4.75),
#    ('keen', 1.0, 'sharp', 4.75),
#    ('funny', 2.3333333333333335, 'suspicious', 2.0),
#    ('outrageous', 2.3333333333333335, 'steep', 2.0),
#    ('perfect', 2.0, 'pure', 2.3333333333333335),
#    ('terrible', 2.625, 'dire', 1.75),
#    ('wide', 1.090909090909091, 'broad', 4.166666666666667),
#    ('good', 1.5853658536585367, 'effective', 2.857142857142857),
#    ('live', 1.5, 'experienced', 3.0),
#    ('terrific', 1.5, 'grand', 3.0),
#    ('mere', 1.5, 'bare', 3.0),
#    ('excited', 1.7999999999999998, 'emotional', 2.5),
#    ('straight', 3.0, 'straightforward', 1.5),
#    ('unique', 3.0, 'alone', 1.5),
#    ('secret', 2.25, 'mysterious', 2.0),
#    ('full', 1.0571428571428572, 'broad', 4.166666666666667),
#    ('terrible', 2.625, 'severe', 1.6666666666666667),
#    ('wild', 2.0, 'angry', 2.142857142857143),
#    ('classified', 3.4, 'separate', 1.25),
#    ('clean', 1.75, 'fresh', 2.4),
#    ('wild', 2.0, 'furious', 2.0),
#    ('preferable', 1.0, 'preferred', 4.0),
#    ('wonderful', 1.3333333333333333, 'grand', 3.0),
#    ('ferocious', 4.0, 'savage', 1.0),
#    ('favorite', 1.0, 'preferred', 4.0),
#    ('reckless', 2.0, 'rash', 2.0),
#    ('disgusting', 2.0, 'distasteful', 2.0),
#    ('pregnant', 1.0, 'fraught', 4.0),
#    ('stark', 1.3333333333333333, 'bare', 3.0),
#    ('fellow', 2.4814814814814814, 'familiar', 1.6111111111111112),
#    ('shameful', 3.0, 'black', 1.3209876543209877),
#    ('whole', 1.4583333333333333, 'solid', 2.6666666666666665),
#    ('untrue', 3.0, 'false', 1.2857142857142856),
#    ('blank', 2.0, 'white', 1.9195402298850575),
#    ('stunned', 2.0, 'stupid', 1.9090909090909092),
#    ('sick', 3.75, 'ill', 1.0),
#    ('sick', 3.75, 'crazy', 1.0),
#    ('virtual', 2.5, 'practical', 1.5),
#    ('good', 1.5853658536585367, 'secure', 2.3333333333333335),
#    ('exclusive', 3.6666666666666665, 'single', 1.0),
#    ('exclusive', 3.6666666666666665, 'sole', 1.0),
#    ('progressive', 3.3529411764705883, 'liberal', 1.0769230769230769),
#    ('peaceful', 1.2, 'passive', 3.0),
#    ('straight', 3.0, 'true', 1.2),
#    ('worried', 3.5999999999999996, 'upset', 1.0),
#    ('honest', 3.0, 'true', 1.2),
#    ('further', 3.5, 'far', 1.0),
#    ('intelligent', 3.5, 'sound', 1.0),
#    ('desperate', 2.0, 'dire', 1.75),
#    ('further', 3.5, 'advanced', 1.0),
#    ('intelligent', 3.5, 'healthy', 1.0),
#    ('clean', 1.75, 'white', 1.9195402298850575),
#    ('terrible', 2.625, 'tremendous', 1.2777777777777777),
#    ('incompetent', 1.0, 'unqualified', 3.3333333333333335),
#    ('extra', 1.0, 'additional', 3.3333333333333335),
#    ('countless', 2.0, 'myriad', 1.6666666666666667),
#    ('stark', 1.3333333333333333, 'blunt', 2.5),
#    ('safe', 1.4210526315789473, 'secure', 2.3333333333333335),
#    ('intimate', 2.0, 'familiar', 1.6111111111111112),
#    ('substantive', 1.5, 'substantial', 2.142857142857143),
#    ('vitriolic', 2.0, 'blistering', 1.6),
#    ('right', 1.4878048780487805, 'powerful', 2.1176470588235294),
#    ('nasty', 1.5714285714285714, 'tight', 2.0),
#    ('quiet', 1.25, 'smooth', 2.5),
#    ('stark', 1.3333333333333333, 'pure', 2.3333333333333335),
#    ('utter', 1.3333333333333333, 'pure', 2.3333333333333335),
#    ('actual', 1.2, 'real', 2.576642335766423),
#    ('strong', 1.1578947368421053, 'solid', 2.6666666666666665),
#    ('seeming', 1.0, 'apparent', 3.083333333333333),
#    ('straight', 3.0, 'heterosexual', 1.0),
#    ('lone', 2.0, 'alone', 1.5),
#    ('dirty', 3.0, 'foul', 1.0),
#    ('golden', 1.0, 'prosperous', 3.0),
#    ('crude', 2.0, 'raw', 1.5),
#    ('confused', 3.0, 'upset', 1.0),
#    ('silly', 3.0, 'giddy', 1.0),
#    ('hollow', 3.0, 'empty', 1.0),
#    ('lucky', 1.0, 'prosperous', 3.0),
#    ('firm', 1.0, 'steady', 3.0),
#    ('magnificent', 1.0, 'brilliant', 3.0),
#    ('literal', 2.0, 'genuine', 1.5),
#    ('ominous', 3.0, 'ill', 1.0),
#    ('symbolic', 1.5, 'emblematic', 2.0),
#    ('straight', 3.0, 'square', 1.0),
#    ('connected', 1.0, 'associate', 3.0),
#    ('live', 1.5, 'known', 2.0),
#    ('honest', 3.0, 'reliable', 1.0),
#    ('perfect', 2.0, 'complete', 1.5),
#    ('distant', 1.0, 'remote', 3.0),
#    ('naked', 1.0, 'bare', 3.0),
#    ('sensible', 2.0, 'reasonable', 1.5),
#    ('special', 1.275, 'limited', 2.2857142857142856),
#    ('open', 1.45, 'undecided', 2.0),
#    ('intimate', 2.0, 'inner', 1.4285714285714286),
#    ('peculiar', 2.0, 'particular', 1.4),
#    ('single', 1.0, 'individual', 2.8),
#    ('quick', 1.375, 'warm', 2.0),
#    ('slanted', 1.0, 'biased', 2.75),
#    ('strong', 1.1578947368421053, 'secure', 2.3333333333333335),
#    ('unsafe', 2.0, 'dangerous', 1.346153846153846),
#    ('dead', 2.4444444444444446, 'short', 1.1),
#    ('upset', 1.0, 'troubled', 2.6666666666666665),
#    ('famous', 2.0, 'notable', 1.3333333333333333),
#    ('square', 1.0, 'solid', 2.6666666666666665),
#    ('firm', 1.0, 'solid', 2.6666666666666665),
#    ('stark', 1.3333333333333333, 'stern', 2.0),
#    ('terrible', 2.625, 'dreadful', 1.0),
#    ('ugly', 1.2857142857142858, 'vile', 2.0),
#    ('bottom', 1.2857142857142858, 'stern', 2.0),
#    ('very', 2.533333333333333, 'identical', 1.0),
#    ('strident', 1.25, 'vociferous', 2.0),
#    ('candid', 1.0, 'blunt', 2.5),
#    ('quiet', 1.25, 'calm', 2.0),
#    ('sound', 1.0, 'audio', 2.5),
#    ('savage', 1.0, 'brutal', 2.5),
#    ('strong', 1.1578947368421053, 'substantial', 2.142857142857143),
#    ('great', 1.2395833333333333, 'heavy', 2.0),
#    ('spiritual', 2.0, 'religious', 1.2272727272727273),
#    ('tough', 1.2121212121212122, 'elusive', 2.0),
#    ('essential', 1.2, 'necessary', 2.0),
#    ('wild', 2.0, 'fantastic', 1.2),
#    ('sensible', 2.0, 'sensitive', 1.2),
#    ('various', 1.0588235294117647, 'diverse', 2.25),
#    ('funny', 2.3333333333333335, 'curious', 1.0),
#    ('unafraid', 1.0, 'secure', 2.3333333333333335),
#    ('funny', 2.3333333333333335, 'comic', 1.0),
#    ('consecutive', 2.3333333333333335, 'serial', 1.0),
#    ('funny', 2.3333333333333335, 'amusing', 1.0),
#    ('strong', 1.1578947368421053, 'warm', 2.0),
#    ('faithful', 1.0, 'close', 2.3055555555555554),
#    ('primary', 1.1282051282051282, 'chief', 2.0384615384615383),
#    ('great', 1.2395833333333333, 'large', 1.8484848484848484),
#    ('divided', 1.5, 'split', 1.5),
#    ('only', 1.4838709677419355, 'alone', 1.5),
#    ('outspoken', 2.2222222222222223, 'candid', 1.0),
#    ('stark', 1.3333333333333333, 'severe', 1.6666666666666667),
#    ('concerned', 1.4705882352941178, 'interested', 1.5),
#    ('disgraceful', 1.6666666666666667, 'black', 1.3209876543209877),
#    ('worldwide', 1.0, 'global', 2.1875),
#    ('fair', 1.4545454545454546, 'reasonable', 1.5),
#    ('wrong', 1.2999999999999998, 'incorrect', 1.6666666666666667),
#    ('square', 1.0, 'substantial', 2.142857142857143),
#    ('good', 1.5853658536585367, 'near', 1.3333333333333333),
#    ('independent', 2.0, 'main', 1.0476190476190477),
#    ('big', 1.045045045045045, 'heavy', 2.0),
#    ('various', 1.0588235294117647, 'several', 1.953703703703704),
#    ('fair', 1.4545454545454546, 'average', 1.4),
#    ('tough', 1.2121212121212122, 'hard', 1.6666666666666667),
#    ('wild', 2.0, 'savage', 1.0),
#    ('unsavory', 1.0, 'distasteful', 2.0),
#    ('wild', 2.0, 'crazy', 1.0),
#    ('fast', 1.0, 'tight', 2.0),
#    ('lucky', 1.0, 'favorable', 2.0),
#    ('unchecked', 1.0, 'unbridled', 2.0),
#    ('triumphant', 1.0, 'victorious', 2.0),
#    ('consistent', 1.0, 'uniform', 2.0),
#    ('thankful', 1.0, 'grateful', 2.0),
#    ('independent', 2.0, 'sovereign', 1.0),
#    ('profound', 1.0, 'heavy', 2.0),
#    ('undetermined', 1.0, 'undecided', 2.0),
#    ('fast', 1.0, 'loyal', 2.0),
#    ('savage', 1.0, 'furious', 2.0),
#    ('unworthy', 1.0, 'vile', 2.0),
#    ('odd', 2.0, 'curious', 1.0),
#    ('renowned', 1.5, 'notable', 1.3333333333333333),
#    ('suited', 2.0, 'fit', 1.0),
#    ('frank', 2.0, 'candid', 1.0),
#    ('apt', 1.0, 'clever', 2.0),
#    ('utter', 1.3333333333333333, 'complete', 1.5),
#    ('peculiar', 2.0, 'curious', 1.0),
#    ('worldwide', 1.0, 'universal', 2.0),
#    ('lone', 2.0, 'sole', 1.0),
#    ('stark', 1.3333333333333333, 'complete', 1.5),
#    ('unruly', 1.0, 'boisterous', 2.0),
#    ('pressing', 1.0, 'urgent', 2.0),
#    ('firm', 1.0, 'loyal', 2.0),
#    ('foul', 1.0, 'distasteful', 2.0),
#    ('unrehearsed', 1.0, 'impromptu', 2.0),
#    ('golden', 1.0, 'favorable', 2.0),
#    ('mad', 2.0, 'crazy', 1.0),
#    ('sound', 1.0, 'heavy', 2.0),
#    ('disgusting', 2.0, 'foul', 1.0),
#    ('loaded', 1.0, 'tight', 2.0),
#    ('stirring', 2.0, 'rousing', 1.0),
#    ('green', 1.5, 'common', 1.3043478260869565),
#    ('wrong', 1.2999999999999998, 'improper', 1.5),
#    ('open', 1.45, 'subject', 1.3333333333333333),
#    ('big', 1.045045045045045, 'large', 1.8484848484848484),
#    ('strong', 1.1578947368421053, 'hard', 1.6666666666666667),
#    ('terrific', 1.5, 'tremendous', 1.2777777777777777),
#    ('advanced', 1.0, 'modern', 1.8888888888888888),
#    ('deserving', 1.0, 'worth', 1.875),
#    ('unimaginable', 1.5, 'impossible', 1.25),
#    ('divided', 1.5, 'separate', 1.25),
#    ('pregnant', 1.0, 'significant', 1.8695652173913044),
#    ('second', 1.2075471698113207, 'instant', 1.5),
#    ('actual', 1.2, 'genuine', 1.5),
#    ('terrific', 1.5, 'fantastic', 1.2),
#    ('clean', 1.75, 'clear', 1.027027027027027),
#    ('sound', 1.0, 'legal', 1.7954545454545456),
#    ('ready', 1.1363636363636365, 'prepared', 1.5714285714285714),
#    ('special', 1.275, 'particular', 1.4),
#    ('good', 1.5853658536585367, 'serious', 1.105263157894737),
#    ('dreadful', 1.0, 'dire', 1.75),
#    ('profound', 1.0, 'fundamental', 1.75),
#    ('ordinary', 1.25, 'average', 1.4),
#    ('right', 1.4878048780487805, 'proper', 1.1666666666666667),
#    ('wonderful', 1.3333333333333333, 'tremendous', 1.2777777777777777),
#    ('open', 1.45, 'capable', 1.1666666666666667),
#    ('old', 1.28, 'previous', 1.3),
#    ('free', 1.1, 'exempt', 1.5),
#    ('innocent', 1.6, 'devoid', 1.0),
#    ('hot', 1.0, 'blistering', 1.6),
#    ('wonderful', 1.3333333333333333, 'fantastic', 1.2),
#    ('good', 1.5853658536585367, 'sound', 1.0),
#    ('nasty', 1.5714285714285714, 'foul', 1.0),
#    ('able', 1.3061224489795917, 'capable', 1.1666666666666667),
#    ('worrisome', 1.0, 'troubling', 1.5),
#    ('upset', 1.0, 'troubling', 1.5),
#    ('square', 1.0, 'straightforward', 1.5),
#    ('live', 1.5, 'hot', 1.0),
#    ('naked', 1.0, 'raw', 1.5),
#    ('coherent', 1.5, 'consistent', 1.0),
#    ('natural', 1.0, 'raw', 1.5),
#    ('open', 1.45, 'clear', 1.027027027027027),
#    ('only', 1.4838709677419355, 'sole', 1.0),
#    ('open', 1.45, 'undetermined', 1.0),
#    ('open', 1.45, 'candid', 1.0),
#    ('loose', 1.3333333333333333, 'liberal', 1.0769230769230769),
#    ('quick', 1.375, 'nimble', 1.0),
#    ('quick', 1.375, 'fast', 1.0),
#    ('productive', 1.0, 'rich', 1.3333333333333333),
#    ('stale', 1.0, 'cold', 1.3333333333333333),
#    ('worrisome', 1.0, 'disturbing', 1.3333333333333333),
#    ('hallowed', 1.0, 'sacred', 1.3333333333333333),
#    ('upset', 1.0, 'disturbing', 1.3333333333333333),
#    ('ugly', 1.2857142857142858, 'unworthy', 1.0),
#    ('happy', 1.0, 'glad', 1.2857142857142856),
#    ('ugly', 1.2857142857142856, 'horrible', 1.0),
#    ('special', 1.275, 'extra', 1.0),
#    ('strident', 1.25, 'raucous', 1.0),
#    ('crooked', 1.0, 'corrupt', 1.25),
#    ('strident', 1.25, 'shrill', 1.0),
#    ('great', 1.2395833333333333, 'keen', 1.0),
#    ('bad', 1.024390243902439, 'unfit', 1.1875),
#    ('rightful', 1.0, 'true', 1.2),
#    ('reliable', 1.0, 'true', 1.2),
#    ('free', 1.1, 'liberal', 1.0769230769230769),
#    ('primary', 1.1282051282051282, 'main', 1.0476190476190477),
#    ('pro', 1.0, 'professional', 1.1764705882352942),
#    ('strong', 1.1578947368421053, 'firm', 1.0),
#    ('worldwide', 1.0, 'general', 1.1358024691358024),
#    ('big', 1.045045045045045, 'liberal', 1.0769230769230769),
#    ('unsavory', 1.0, 'offensive', 1.1),
#    ('free', 1.1, 'devoid', 1.0),
#    ('handsome', 1.0, 'liberal', 1.0769230769230769),
#    ('big', 1.045045045045045, 'handsome', 1.0),
#    ('golden', 1.0, 'lucky', 1.0),
#    ('fast', 1.0, 'firm', 1.0),
#    ('amusing', 1.0, 'comic', 1.0),
#    ('aghast', 1.0, 'shocked', 1.0),
#    ('healthy', 1.0, 'sound', 1.0),
#    ('profound', 1.0, 'sound', 1.0)],
#   'entity_cluster': ['Donald J. Trump',
#    'Donald Trump',
#    'Donald Trump Jr.',
#    'DONALD J. TRUMP',
#    'D. C. Donald Trump',
#    'Donald Trump Trump',
#    'F*ck Donald Trump']},
#  2734: {'adj_pairs': [], 'entity_cluster': ['Ivanka Trump']}}
